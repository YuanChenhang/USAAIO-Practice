# %% [markdown]
# <a href="https://colab.research.google.com/github/YuanChenhang/USAAIO-Practice/blob/main/Round_1%2C_Problem_1%2C_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1, Part 2
# 2025 USA-NA-AIO Round 1, Problem 1, Part 2
# ## **Part 2 (10 points, non-coding task)**
#
# The recursive equation that defines the sequence in this problem can be written in a matrix form:
#
# $$ \begin{bmatrix}F_n \\ F_{n-1} \end{bmatrix} = \mathbf{A} \begin{bmatrix} F_{n-1} \\ F_{n-2} \end{bmatrix}, \ \forall \ n \geq 2 , $$
#
# where $\mathbf{A} \in \Bbb R^{2 \times 2}$.
#
# **Compute $\mathbf{A}$.**
#
# * Reasoning is not required.
#
# * The value of each entry in $\mathbf{A}$ must be exact. For instance, the following values are exact: $\sqrt{3}$, $\frac{2}{\sqrt{7}}$, $\pi + \frac{3}{8}$, $e^2$, $\sin 40^\circ$, $\log 18$. However, their float approximations are not exact.

# %% [markdown]
# # **First we have:**
#
# $$ \begin{bmatrix} F_n \\ F_{n-1} \end{bmatrix} = A \begin{bmatrix} F_{n-1} \\ F_{n-2} \end{bmatrix} $$
#
# <br>
#
# # **set**
#
# $$ A = \begin{bmatrix} a & b \\ c & d \end{bmatrix} $$
#
# <br>
#
# # **Then times it**
# \begin{bmatrix}
# aF_{n-1} + bF_{n-2} \\
# cF_{n-1} + dF_{n-2}
# \end{bmatrix}
#
# <br>
#
# # **So it is equal:**
#
# \begin{bmatrix}
# F_{n-1} + F_{n-2} \\
# F_{n-1}
# \end{bmatrix}
#
# because the formula is $F_n = F_{n-1} + F_{n-2}$, and the second line is $F_{n-1}$
#
# # **so the number equals one by one:**
#
# First line: $aF_{n-1} + bF_{n-2} = F_{n-1} + F_{n-2} → a = 1,\ b = 1$
#
# <br>
#
# Second line: $cF_{n-1} + dF_{n-2} = F_{n-1} → c = 1,\ d = 0$
#
# <br>
#
# # **so the final answer is:**
#
# <br>
#
# A = \begin{bmatrix}
# 1 & 1 \\
# 1 & 0
# \end{bmatrix}
