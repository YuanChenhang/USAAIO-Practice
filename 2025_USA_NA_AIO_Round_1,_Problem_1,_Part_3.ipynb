# %% [markdown]
# <a href="https://colab.research.google.com/github/YuanChenhang/USAAIO-Practice/blob/main/2025_USA_NA_AIO_Round_1%2C_Problem_1%2C_Part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1, Part 3
# 2025 USA-NA-AIO Round 1, Problem 1, Part 3
# ## **Part 3 (10 points, non-coding task)**
#
# **Explain why $\mathbf{A}$ is a symmetric matrix.**
#
# # **Because $A = A⊤$**
